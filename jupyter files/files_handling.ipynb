# %% [markdown]
# File Handing

# %%
f = open("abc.txt", "w")
print("file name", f.name);
print("mode", f.mode);
print("open vs close ", f.closed)
f.close()
print("open vs close ", f.closed)
# Out:
# file name abc.txt
# mode w
# open vs close  False
# open vs close  True
