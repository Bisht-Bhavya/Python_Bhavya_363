# %% [markdown]
# Functions

# %%
def sum(a,b):
    return a+b
c = 2
d = 3
print(sum(1,2))
print(sum(c,d))
print(sum(a=5, b = 5))
# Out:
# 3
# 5
# 10

# %%
def pet(name, type="dog"):
    print(f"hello this is {name}")
    print(f"hello this is {type}")
pet("max")
pet('cat', 'abcd')
# Out:
# hello this is max
# hello this is dog
# hello this is cat
# hello this is abcd
